# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n-cls.pt")

# %%
learning_rate = 0.001
batch_size = 256
num_epochs = 30
image_size = 512

# %%
results = model.train(data="/Users/hp/TopicosIA/parcial1TIA/entrenamiento/Cursodataset/", epochs=num_epochs, imgsz=image_size, batch=batch_size)
# Out:
# New https://pypi.org/project/ultralytics/8.0.212 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.210  Python-3.11.5 torch-2.1.0+cpu CPU (AMD Ryzen 5 3550H with Radeon Vega Mobile Gfx)
# ...
